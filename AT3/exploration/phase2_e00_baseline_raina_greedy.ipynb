# %% [markdown]
# # Phase 2 — E0: Baseline with Raina's prep (greedy)

# %%
import sys
from pathlib import Path
nb_dir = Path('.').resolve()
sys.path.insert(0, str(nb_dir / "output"))
import importlib, exp_runner
importlib.reload(exp_runner)
from exp_runner import ExperimentConfig, run_experiment, evaluate_only
print("exp_runner loaded from", exp_runner.__file__)
# Out:
# exp_runner loaded from /home/coezbek/dev/2026/AT3_training/assignment3_notebook/output/exp_runner.py

# %% [markdown]
# Re-run of the Phase 1 architecture (EfficientNet B0 + Transformer with 3 layers, 8 heads, d_model=512) using **Raina's data prep** (no `<num>` token). Greedy decoding. This is the new baseline for all Phase 2 deltas.

# %%
cfg = ExperimentConfig(
    run_name='phase2_e0_baseline_raina_greedy',
    output_dir='output/phase2_results',
    epochs=15,
    batch_size=128,
    lr=1e-4,
    decoding='greedy',
)
metrics_e0 = run_experiment(cfg)
metrics_e0
# Out:
# [phase2_e0_baseline_raina_greedy] device=cuda
# (null): No such file or directory
# /home/coezbek/dev/2026/AT3_training/.venv/lib/python3.13/site-packages/torch/nn/functional.py:6682: UserWarning: Mem Efficient attention on Current AMD GPU is still experimental. Enable it with TORCH_ROCM_AOTRITON_ENABLE_EXPERIMENTAL=1. (Triggered internally at /pytorch/aten/src/ATen/native/transformers/hip/sdp_utils.cpp:383.)
#   attn_output = scaled_dot_product_attention(
# /home/coezbek/dev/2026/AT3_training/.venv/lib/python3.13/site-packages/torch/nn/functional.py:6682: UserWarning: Flash Efficient attention on Current AMD GPU is still experimental. Enable it with TORCH_ROCM_AOTRITON_ENABLE_EXPERIMENTAL=1. (Triggered internally at /pytorch/aten/src/ATen/native/transformers/hip/sdp_utils.cpp:323.)
#   attn_output = scaled_dot_product_attention(
# [phase2_e0_baseline_raina_greedy] ep01/15 train=4.6704  val=3.8775  lr=1.00e-04  t=43.9s
# [phase2_e0_baseline_raina_greedy] ep02/15 train=3.7482  val=3.5611  lr=1.00e-04  t=44.3s
# [phase2_e0_baseline_raina_greedy] ep03/15 train=3.4419  val=3.3948  lr=1.00e-04  t=44.4s
# [phase2_e0_baseline_raina_greedy] ep04/15 train=3.2216  val=3.2836  lr=1.00e-04  t=44.5s
# [phase2_e0_baseline_raina_greedy] ep05/15 train=3.0450  val=3.2187  lr=1.00e-04  t=44.6s
# [phase2_e0_baseline_raina_greedy] ep06/15 train=2.8900  val=3.1792  lr=1.00e-04  t=44.5s
# [phase2_e0_baseline_raina_greedy] ep07/15 train=2.7486  val=3.1576  lr=1.00e-04  t=44.5s
# [phase2_e0_baseline_raina_greedy] ep08/15 train=2.6153  val=3.1435  lr=1.00e-04  t=44.6s
# [phase2_e0_baseline_raina_greedy] ep09/15 train=2.4899  val=3.1494  lr=1.00e-04  t=44.4s
# [phase2_e0_baseline_raina_greedy] ep10/15 train=2.3747  val=3.1444  lr=1.00e-04  t=44.6s
# [phase2_e0_baseline_raina_greedy] ep11/15 train=2.2610  val=3.1649  lr=1.00e-04  t=44.3s
# [phase2_e0_baseline_raina_greedy] ep12/15 train=2.1192  val=3.1816  lr=5.00e-05  t=44.5s
# [phase2_e0_baseline_raina_greedy] early stop at epoch 12
# [phase2_e0_baseline_raina_greedy] DONE  val_BLEU-4=0.2488  test_BLEU-4=0.2494  test_CIDEr=0.9960
# {'run_name': 'phase2_e0_baseline_raina_greedy',
#  'best_val_loss': 3.1435395346747503,
#  'epochs_run': 12,
#  'decoding': 'greedy',
#  'beam_width': None,
#  'length_penalty': None,
#  'val_BLEU-1': 0.6341545446901846,
#  'val_BLEU-2': 0.45802758419425305,
#  'val_BLEU-3': 0.33139167966392324,
#  'val_BLEU-4': 0.2487893331493249,
#  'val_CIDEr': 0.9614399882242839,
#  'test_BLEU-1': 0.625229894666475,
#  'test_BLEU-2': 0.4460203504146647,
#  'test_BLEU-3': 0.32540405819478235,
#  'test_BLEU-4': 0.24937507936898443,
#  'test_CIDEr': 0.9959623104205599}
